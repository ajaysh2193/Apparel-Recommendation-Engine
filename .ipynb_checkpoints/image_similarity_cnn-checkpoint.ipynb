# %% [markdown]
# # Apparel Recommendations usin Convolutional Neural Network

# %% [markdown]
# ## Get the feature vectors of all apparel images

# %% [markdown]
# Running this cell will take time, you can skip running this cell. you can download the feature vectors from given link
#
# 16k_data_cnn_features.npy: https://drive.google.com/open?id=0BwNkduBnePt2c1BkNzRDQ1dOVFk
# bottleneck_features_cnn.npy : https://drive.google.com/open?id=0BwNkduBnePt2ODRxWHhUVzIyWDA

# %%
# https://gist.github.com/fchollet/f35fbc80e066a49d65f1688a7e99f069
# https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras import applications


'''
# dimensions of our images.
img_width, img_height = 224, 224

top_model_weights_path = 'bottleneck_fc_model.h5'
train_data_dir = 'images2/'
nb_train_samples = 16042
epochs = 50
batch_size = 1


# this fucntion geenrates features for all the images and saves them to a file.
def save_bottlebeck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)
    # build the VGG16 network
    model = applications.VGG16(include_top=False, weights='imagenet')
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_train = model.predict_generator(generator, nb_train_samples // batch_size)
    np.save(open('bottleneck_features_cnn.npy', 'wb'), bottleneck_features_train)

save_bottlebeck_features()


# read each of the files from the directory
datagen = ImageDataGenerator(rescale=1. / 255)
generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
        
        
asins = []
for i in generator.filenames:
    asins.append(i[2:-5])

a = np.load('bottleneck_features_cnn.npy')
b = a.reshape((16042,25088))

#save the CNN features for 16K products at 16k_data_cnn_features.npy
np.save(open('16k_data_cnn_features.npy', 'wb'), b)

'''
# Out:
# Found 16042 images belonging to 1 classes.

# %% [markdown]
# ## get the most similar apparels using euclidean distance measure

# %%
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import requests
from PIL import Image

# %%
def display_img(url):
    # we get the url of the apparel and download it
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    # we will display it in notebook 
    plt.imshow(img)
    plt.show()

# %%
import pandas as pd
data = pd.read_pickle('16k_apperal_data_preprocessed')

# %%
from IPython.display import display, HTML 
print(pdists)
def get_similar_products_cnn(doc_id, num_results):
    pairwise_dist = pairwise_distances(b, b[doc_id].reshape(1,-1))
    # np.argsort will return indices of the smallest distances
    indices = np.argsort(pairwise_dist.flatten())[0:num_results]
    #pdists will store the the smallest distances
    pdists  = np.sort(pairwise_dist.flatten())[0:numresults]
    for i in indices:
        url="<a href='www.amazon.com/dp/"+asins[i]+"'> Product Page </a>"
        for j in  data['medium_image_url'].loc[data['asin']==asins[i]]:
            print('Image Url',j)
            print ('Amazon Url: www.amzon.com/dp/'+ asins[i])
            display_img(j)
            
get_similar_products_cnn(5)
# 5 is good
# 10 is ok
# Out:
# [    3  1798  2997  1881  9264  8921  2007  5297 11084]
# [  0.          33.45090103  42.62312317  43.06540298  43.08408356
#   43.08499527  43.32542801  43.60673523  43.69728851]
# https://images-na.ssl-images-amazon.com/images/I/31Aj97p-cRL._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31dk5HMhO-L._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31cAWqsltQL._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41j5Mqmx%2BnL._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31nmgRIG40L._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31i1hW3lc3L._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31H6I0pSbnL._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31Fnlb8mY2L._SL160_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31WwmfHIShL._SL160_.jpg
